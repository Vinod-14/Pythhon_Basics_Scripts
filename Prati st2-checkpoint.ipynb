# %%
# import librararies
import numpy as np
import pandas as pb
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  LogisticRegression
from sklearn.linear_model import  LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
h_f=pb.read_csv("https://raw.githubusercontent.com/Premalatha-success/Yhills_July12_Analytics/main/concrete.csv")

# %%
h_f.head(6)
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4   154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# 5   255.0    0.0    0.0  192.0           0.0      889.8    945.0   90
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29
# 5     21.86

# %%
h_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cement        1030 non-null   float64
#  1   slag          1030 non-null   float64
#  2   ash           1030 non-null   float64
#  3   water         1030 non-null   float64
#  4   superplastic  1030 non-null   float64
#  5   coarseagg     1030 non-null   float64
#  6   fineagg       1030 non-null   float64
#  7   age           1030 non-null   int64
#  8   strength      1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
h_f["cement"]=h_f["cement"].replace(to_replace=0,value=np.nan)
h_f["cement"]=h_f["cement"].astype(float)
median1=h_f["cement"].median()
h_f["cement"].replace(np.nan,median1,inplace=True)

# %%
h_f["slag"]=h_f["slag"].replace(to_replace=0,value=np.nan)
h_f["slag"]=h_f["slag"].astype(float)
median2=h_f["slag"].median()
h_f["slag"].replace(np.nan,median2,inplace=True)

# %%
h_f["ash"]=h_f["ash"].replace(to_replace=0,value=np.nan)
h_f["ash"]=h_f["ash"].astype(float)
median4=h_f["ash"].median()
h_f["ash"].replace(np.nan,median4,inplace=True)

# %%
h_f["water"]=h_f["water"].replace(to_replace=0,value=np.nan)
h_f["water"]=h_f["water"].astype(float)
median5=h_f["water"].median()
h_f["water"].replace(np.nan,median5,inplace=True)

# %%
h_f["superplastic"]=h_f["superplastic"].replace(to_replace=0,value=np.nan)
h_f["superplastic"]=h_f["superplastic"].astype(float)
median6=h_f["superplastic"].median()
h_f["superplastic"].replace(np.nan,median6,inplace=True)

# %%
h_f["coarseagg"]=h_f["coarseagg"].replace(to_replace=0,value=np.nan)
h_f["coarseagg"]=h_f["coarseagg"].astype(float)
median7=h_f["coarseagg"].median()
h_f["coarseagg"].replace(np.nan,median7,inplace=True)

# %%
h_f["fineagg"]=h_f["fineagg"].replace(to_replace=0,value=np.nan)
h_f["fineagg"]=h_f["fineagg"].astype(float)
median8=h_f["fineagg"].median()
h_f["fineagg"].replace(np.nan,median8,inplace=True)

# %%
h_f["age"]=h_f["age"].replace(to_replace=0,value=np.nan)
h_f["age"]=h_f["age"].astype(float)
median9=h_f["age"].median()
h_f["age"].replace(np.nan,median9,inplace=True)

# %%
h_f["strength"]=h_f["strength"].replace(to_replace=0,value=np.nan)
h_f["strength"]=h_f["strength"].astype(float)
median00=h_f["strength"].median()
h_f["strength"].replace(np.nan,median00,inplace=True)

# %%
h_f.head(6)
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg   age  \
# 0   141.3  212.0  121.4  203.5           9.4      971.8    748.5  28.0
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2  14.0
# 2   250.0  135.7   95.7  187.4           5.5      956.9    861.2  28.0
# 3   266.0  114.0  121.4  228.0           9.4      932.0    670.0  28.0
# 4   154.8  183.4  121.4  193.3           9.1     1047.4    696.7  28.0
# 5   255.0  135.7  121.4  192.0           9.4      889.8    945.0  90.0
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29
# 5     21.86

# %%
bo=h_f.duplicated()
print(bo.sum())
h_f[bo]
# Out:
# 25
#      cement   slag    ash  water  superplastic  coarseagg  fineagg   age  \
# 278   425.0  106.3  121.4  153.5          16.5      852.1    887.1   3.0
# 298   425.0  106.3  121.4  153.5          16.5      852.1    887.1   3.0
# 400   362.6  189.0  121.4  164.9          11.6      944.7    755.8   3.0
# 420   362.6  189.0  121.4  164.9          11.6      944.7    755.8   3.0
# 463   362.6  189.0  121.4  164.9          11.6      944.7    755.8  56.0
# 468   252.0  135.7  121.4  185.0           9.4     1111.0    784.0  28.0
# 482   425.0  106.3  121.4  153.5          16.5      852.1    887.1  91.0
# 493   362.6  189.0  121.4  164.9          11.6      944.7    755.8  91.0
# 517   425.0  106.3  121.4  153.5          16.5      852.1    887.1  56.0
# 525   362.6  189.0  121.4  164.9          11.6      944.7    755.8  28.0
# 527   425.0  106.3  121.4  153.5          16.5      852.1    887.1  91.0
# 576   362.6  189.0  121.4  164.9          11.6      944.7    755.8   7.0
# ...

# %%
h_f.boxplot(column=["strength"])
# Out:
# <AxesSubplot:>

# %%
def remove_outlier(col1):
    sorted(col1)
    Q1,Q3=col1.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range=Q1-(1.5*IQR)
    upper_range=Q3+(1.5*IQR)
    return lower_range,upper_range

# %%
lowestrength,upperstrength=remove_outlier(h_f["strength"])
h_f["strength"]=np.where(h_f["strength"]>upperstrength,upperstrength,h_f["strength"])
h_f["strength"]=np.where(h_f["strength"]<lowestrength,lowestrength,h_f["strength"])

# %%
x=h_f.drop("strength",axis=1)
y=h_f[["strength"]]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)

# %% [markdown]
# FIT linear model

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
score = lr.score(x_test,y_test)
print('predcted score is : {}',format(score))
print('..................................')
y_predict = lr.predict(x_test)
print('mean_sqrd_error is ==',mean_squared_error(y_test,y_predict))
rms = np.sqrt(mean_squared_error(y_test,y_predict)) 
print('root mean squared error is == {}'.format(rms))
# Out:
# predcted score is : {} 0.6373677558979071
# ..................................
# mean_sqrd_error is == 105.24016699194637
# root mean squared error is == 10.25866302165864

# %%
plt.figure(figsize=[17,8])
plt.scatter(y_predict,y_test)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red')
plt.xlabel('predicted')
plt.ylabel('orignal')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
rnd= RandomForestRegressor(ccp_alpha=0.0)
fit_rnd= rnd.fit(x_train,y_train)
print('score is:-',rnd.score(x_test,y_test))
print('........................................')
print('mean_sqrd_error is==',mean_squared_error(y_test,rnd.predict(x_test)))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,rnd.predict(x_test))))
# Out:
# C:\Users\Win10\AppData\Local\Temp\ipykernel_5884\2436965796.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   fit_rnd= rnd.fit(x_train,y_train)
# score is:- 0.8932703454231664
# ........................................
# mean_sqrd_error is== 30.97420831528834
# root_mean_squared error of is== 5.565447719212565
